# %%
import matplotlib.pyplot as plt

# %%
x_data = [1,2,3,4,5,6,7,8,9]
# y_data = [1,2,3,4,5]
y_data = [x**2 for x in x_data]

# %%
plt.plot(x_data, y_data)
plt.title("This is a tile")
plt.xlabel("X_data, normally X axis title")
plt.ylabel("Y_data, normally Y axis title")
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
import numpy as np

plt.figure(figsize=(50,20))

plt.subplot(1,3,1)
plt.plot(x_data, y_data)

plt.subplot(1,3,2)
plt.plot(x_data, np.sin(y_data))

plt.subplot(1,3,3)
plt.plot(x_data, np.cos(y_data))

# %% [markdown]
# ### Figure Size

# %%
# This figsize controls the size of the display of the data that is displayed
